# %%
# Cleaning the data from the database and integrating with Groq LLM
# This script is part of a larger system that manages parts data and provides search functionality.

import pandas as pd
import sqlite3

# %%
# Define the path to your database 
db_path = 'parts.db'
table = 'parts'

# %%
try : 
    conn = sqlite3.connect(db_path)
    print(f"Successfully connected")
    df = pd.read_sql_query(f"SELECT * FROM {table}", conn)
    conn.execute(""" UPDATE parts  
                 SET AS Category""")
    print(f"Data loaded successfully from {table} table.")
except sqlite3.Error as e:
    print(f"An error occurred: {e}")
finally:
    if conn:
        conn.close()
        print("Connection closed.")
# Out:
# Successfully connected
# An error occurred: near "AS": syntax error
# Connection closed.

# %%
import pandas as pd
import sqlite3  

# Connect to your database
conn = sqlite3.connect('parts.db')  # update with your actual database

# Optional: run the update query first
conn.execute("""
    UPDATE parts
    SET category = 'brakes'
    WHERE category = 'Breaks';
""")
conn.commit()

# %%
query = "SELECT * FROM parts;"
df = pd.read_sql_query(query, conn)
df.head()
# Out:
#   id TransactionID        Date CustomerID         PartNo  Quantity   Rate  \
# 0  0          4269  21-01-2023   CUST-342  SDT10193(STD)         3  12.89
# 1  1          8603  22-06-2024   CUST-834      M748A-STD         2   8.97
# 2  2          5669  17-09-2024   CUST-829      KYB334698         1   4.72
# 3  3           958  13-11-2023   CUST-162    04371-60070         1   5.46
# 4  4          7117  05-10-2024   CUST-328         GWT131         1   5.95
#
#   TotalPrice    PartDescription Category       Source  VehicleMake
# 0      38.67         CLUTCHDISK   Others       Source        Honda
# 1      17.94     LOWER ARM BUSH   Engine  Aftermarket  VehicleMake
# 2       4.72            ENGMATE   Others          OEM       Toyota
# 3       5.46  ENGINE INSULATION   Others          OEM       Nissan
# 4       5.95     SHOCK ABSORBER   Engine  Aftermarket   Mitsubishi

# %%
df['Category'].unique()
# Out:
# array(['Others', 'Engine', 'fuel', 'Body', 'brakes'], dtype=object)

# %%
categories = df['Category'].unique()
print(f"Unique categories found: {categories}")
# Out:
# Unique categories found: ['Others' 'Engine' 'fuel' 'Body' 'Breaks']

# %%
""" Cleaning the categories and classifying them into 5 main categories.
1.Engine
2.Body
3.Breaks
4.Fuel
5.Others
"""
# This dictionary maps each of your specific categories to a main one.
# It's more precise than the previous keyword-based approach.
exact_mapping = {
    # Engine
    'Engines & Systems': 'Engine',
    'Engine Parts': 'Engine',
    'engine Parts': 'Engine',
    'Engines & Engine Parts': 'Engine',
    'Engines & Drivetrain': 'Engine',
    'Engines & Cars': 'Engine',
    'Engine Mounts': 'Engine',
    'Cooling System': 'Engine',
    'Ignition': 'Engine',
    'Valves': 'Engine',
    'Gaskets & Seals': 'Engine',
    'Belts & Hoses': 'Engine',
    'Drivetrain': 'Engine',
    'Air Filtration': 'Engine',
    
    # Body
    'Suspension': 'Body',
    'Suspenders': 'Body', # Assumed typo for Suspension
    'Body & Trim': 'Body',
    
    # Fuel
    'Fuel Systems': 'fuel',
    'Fuel System': 'fuel',
    
    # Brakes
    'BrakingSystem': 'Brakes',
    'Braking System': 'Brakes',
    'Braking Systems': 'Brakes',
    
    # Others (Steering, Fluids, Filters, and miscellaneous)
    'Power Steoring': 'Others', # Typo for Steering
    'Steering': 'Others',
    ' steering': 'Others',
    'Fluids & Chemicals': 'Others',
    'Filtration': 'Others',
# 1575  43.80       87.6      ENGINE INSULATOR   Others          OEM
# 549   16.74      33.48                PISTON   Others       Source
# 1266  13.30       13.3          GEAR FILTER    Others          OEM
# 2237   3.33       20.0            SPARK PLUG   Others          OEM
#
#       VehicleMake
# 1775       Toyota
# 815        Nissan
# 492        Nissan
# 2938       Toyota
# 1848       Nissan
# 913        Toyota
# 2823   Mitsubishi
# 1373   Mitsubishi
# 1713       Toyota
# 1206       Toyota
# 354         Honda
# 1394       Toyota
# 1916       Toyota
# 2763       Nissan
# 2459       Toyota
# 2651   Mitsubishi
# 968       Generic
# 683         Honda
# 1153   Mitsubishi
# 2744       Nissan
# 1809       Toyota
# 2397       Nissan
# 2493       Toyota
# 832       Generic
# 2608       Nissan
# 69         Toyota
# 7          Nissan
# 562   VehicleMake
# 1233       Toyota
# 2497        Honda
# 2797       Toyota
# 2746       Toyota
# 1873   Mitsubishi
# 128         Honda
# 2092       Toyota
# 319    Mitsubishi
# 2447       Nissan
# 2261       Toyota
# 1708       Toyota
# 664    Mitsubishi
# 1078       Nissan
# 2623       Nissan
# 894         Honda
# 2077       Toyota
# 1091       Toyota
# 1716       Nissan
# 1575       Toyota
# 549        Toyota
# 1266       Toyota
# 2237       Toyota

# %%
df.head(10)
# Out:
#   id TransactionID        Date CustomerID         PartNo  Quantity   Rate  \
# 0  0          4269  21-01-2023   CUST-342  SDT10193(STD)         3  12.89
# 1  1          8603  22-06-2024   CUST-834      M748A-STD         2   8.97
# 2  2          5669  17-09-2024   CUST-829      KYB334698         1   4.72
# 3  3           958  13-11-2023   CUST-162    04371-60070         1   5.46
# 4  4          7117  05-10-2024   CUST-328         GWT131         1   5.95
# 5  5          5262  04-08-2024   CUST-523    04495-06050         1  16.77
# 6  6          2122  18-03-2025   CUST-516  SDT10193(STD)         3  17.22
# 7  7          4842  17-09-2024   CUST-438     DIAMBD-502         2  14.88
# 8  8          2847  09-02-2023   CUST-151    11011-38050         3  10.72
# 9  9          6858  06-11-2023   CUST-913         72-452         1   9.41
#
#   TotalPrice    PartDescription Category       Source  VehicleMake
# 0      38.67         CLUTCHDISK   Others       Source        Honda
# 1      17.94     LOWER ARM BUSH   Others  Aftermarket  VehicleMake
# 2       4.72            ENGMATE   Others          OEM       Toyota
# 3       5.46  ENGINE INSULATION   Others          OEM       Nissan
# 4       5.95     SHOCK ABSORBER   Others  Aftermarket   Mitsubishi
# 5      16.77            GROMMET   Others  Aftermarket  VehicleMake
# 6      51.66      THRUST WASher   Others  Aftermarket       Nissan
# 7      29.76        FUEL FILTER   Others  Aftermarket       Nissan
# 8      32.16         air filter   Others  Aftermarket      Generic
# 9       9.41       PETROLLOGGLE   Others       Source        Honda

# %%
df.to_csv('cleaned_parts.csv', index=False)

# %%
df["Category"=="Breaks"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Cartylst\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df["Category"=="Breaks"].sum()
#
# File d:\Cartylst\.venv\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File d:\Cartylst\.venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: False
